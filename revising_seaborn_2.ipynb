# %% [markdown]
# # Data Visualization - Seaborn

# %% [markdown]
# ### 1. Numerical Data Plotting
#  - relplot()
#  - scatterplot()
#  - lineplot()
#
# ### 2. Categorical Data Plotting
#  - catplot()
#  - boxplot()
#  - stripplot()
#  - swarmplot()
#
# ### 3. Visualizing Distribution of the Data
#  - distplot()
#  - kdeplot()
#  - jointplot()
#  - rugplot()
#
# ### 4. Linear Regression and Relationship
#  - regplot()
#  - lmplot()
#
# ### 5. controlling Plotted Figure Aesthetics
#  - figure styling
#  - axes styling
#  - color palettes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from numpy.random import randn

# %%
sns.set(style = 'darkgrid')

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Relational Plot

# %%
sns.relplot(x = "total_bill", y="tip", data = tips)

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_clean_axis',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'map',
#  'map_dataframe',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels']

# %%
sns.relplot(x = "total_bill", y = "tip", data = tips, hue = "smoker")

# %%
tips['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = "total_bill", y = "tip", data = tips, hue = "smoker", style = "time")
### categorical palettes

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "size", data = tips)
### qualitative palettes

# %%
sns.relplot(x = "total_bill", y="tip", hue = "size", data = tips, palette = "ch:r=-0.5, l=0.75")

# %%
sns.relplot(x = "total_bill", y = "tip", data = tips, size = "size")

# %%
sns.relplot(x = "total_bill", y = "tip", data = tips, size = "size", sizes = (15, 200))
# sizes = (15, 200) => lowest size=15, highest size=200, others=in-between values

# %%
sns.relplot(x = "total_bill", y = "tip", data = tips, hue = "size", size = "size", sizes = (15, 200))

# %% [markdown]
# ### LinePlot

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))

# %%
df.head()
# Out:
#    time     value
# 0     0  1.737749
# 1     1  1.291785
# 2     2  0.233323
# 3     3  0.370245
# 4     4  1.553300

# %%
sns.relplot(x = "time", y = "value", kind = "line", data = df)

# %%
df = pd.DataFrame(randn(500, 2).cumsum(axis = 0), columns = ["time", "value"])

# %%
df.head()
# Out:
#        time     value
# 0 -0.753683 -1.791284
# 1 -0.194281 -0.269435
# 2 -1.144534 -0.011953
# 3 -2.440460 -1.537038
# 4 -2.919081 -1.507378

# %%
sns.relplot(x = "time", y = "value", kind = "line", data = df)

# %%
sns.relplot(x = "time", y = "value", kind = "line", data = df, sort = False)

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = "timepoint", y = "signal", kind = "line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal", kind = "line", data = fmri, ci = False)

# %%
sns.relplot(x = "timepoint", y = "signal", kind = "line", data = fmri, ci = 'sd')

# %%
sns.relplot(x = "timepoint", y = "signal", estimator = None, kind = "line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "event", kind = "line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "event", kind = "line", data = fmri, ci = False)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "region", style = "event", kind = "line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "region", style = "event", kind = "line", data = fmri, markers = True)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "region", style = "event", kind = "line", data = fmri, markers = True, dashes = False)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "event", style = "event", kind = "line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "region", units = "subject", estimator = None, kind = "line", data = fmri)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "region", units = "subject", estimator = None, kind = "line", data = fmri.query("event == 'stim'"))

# %%
dots = sns.load_dataset('dots').query("align == 'dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x = "time", y = "firing_rate", kind = "line", data = dots)

# %%
sns.relplot(x = "time", y = "firing_rate", hue = "coherence", kind = "line", data = dots)

# %%
sns.relplot(x = "time", y = "firing_rate", hue = "coherence", style = "choice", kind = "line", data = dots)

# %%
palette = sns.cubehelix_palette(light = 0.8, n_colors = 6)
sns.relplot(x = "time", y = "firing_rate", hue = "coherence", style = "choice", kind = "line", data = dots, palette = palette)

# %%
sns.relplot(x = "time", y = "firing_rate", size = "coherence", style = "choice", kind = "line", data = dots)

# %%
sns.relplot(x = "time", y = "firing_rate", size = "coherence", style = "choice", kind = "line", data = dots, sizes = (1, 5))

# %%
sns.relplot(x = "time", y = "firing_rate", size = "coherence", style = "choice", hue = "coherence", kind = "line", data = dots, sizes = (1, 5))

# %%
sns.relplot(x = "time", y = "firing_rate", size = "choice", style = "choice", hue = "coherence", kind = "line", data = dots, sizes = (1, 5))

# %%
df = pd.DataFrame(dict(time = pd.date_range('2019-06-02', periods = 500), value = randn(500).cumsum()))

# %%
df.head()
# Out:
#         time     value
# 0 2019-06-02 -0.585607
# 1 2019-06-03  1.624382
# 2 2019-06-04  0.069615
# 3 2019-06-05 -0.615944
# 4 2019-06-06 -1.429787

# %%
g = sns.relplot(x = "time", y = "value", kind = "line", data = df)
g.fig.autofmt_xdate()

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "time", data = tips)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "size", data = tips)

# %%
sns.relplot(x = "timepoint", y = "signal", hue = "subject", col = "region", row = "event", height = 3, kind = "line", estimator = None, data = fmri)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "size", data = tips, col_wrap = 3)

# %%
sns.relplot(x = "total_bill", y = "tip", hue = "smoker", col = "size", data = tips, col_wrap = 3, height = 3)

# %%
sns.lineplot(x = "total_bill", y = "tip", data = tips)

# %%
fmri.head(10)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# 5      s9         18  stim  parietal -0.103513
# 6      s8         18  stim  parietal -0.064408
# 7      s7         18  stim  parietal -0.060526
# 8      s6         18  stim  parietal -0.007029
# 9      s5         18  stim  parietal -0.040557

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region",  data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event", data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event", markers = True, data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event", markers = True, ci = None, data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "region", style = "event", markers = True, ci = 50, err_style = "bars", data = fmri)

# %%
sns.lineplot(x = "timepoint", y = "signal", hue = "event", units = "subject", estimator = None, lw = 1, data = fmri.query("region == 'frontal'"))

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.lineplot(x = "time", y = "firing_rate", hue = "coherence", style = "choice", data = dots)

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "sex", size = "size")

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips, hue = "sex", size = "size", style = "time")

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x = "sepal_length", y = "petal_length", data = iris)

# %%
sns.scatterplot(x = "sepal_length", y = "petal_length", hue = "species", data = iris)

# %% [markdown]
# ### Categorical Data plotting

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Catplot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = "day", y = "total_bill", data = tips)

# %%
sns.catplot(x = "total_bill", y = "day", data = tips)

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, jitter = False)

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "swarm")

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "swarm", hue = "sex")

# %%
sns.catplot(x = "smoker", y = "tip", data = tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = "smoker", y = "tip", data = tips, order = ["No", "Yes"])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Boxplot

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", data = tips)

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", hue = "sex", data = tips)

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", hue = "time", data = tips)

# %%
sns.catplot(x = "day", y = "total_bill", kind = "box", data = tips, hue = "sex", dodge = False)

# %% [markdown]
# ### Boxenplot

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = "color", y = "price", kind = "boxen", data = diamonds.sort_values('color'))

# %%
sns.catplot(x = "color", y = "price", kind = "boxen", data = diamonds)

# %%
sns.catplot(x = "day", y = "total_bill", kind = "boxen", data = tips, dodge = False)

# %% [markdown]
# ### ViolinPlot

# %%
sns.catplot(x = "total_bill", y = "day", hue = "time", kind = "violin", data = tips)

# %%
sns.catplot(x = "total_bill", y = "day", hue = "time", kind = "box", data = tips)

# %%
tips[(tips['time'] == 'Lunch') & (tips['day'] == 'Sat')]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
tips[(tips['time'] == 'Dinner') & (tips['day'] == 'Sat')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 19        20.65  3.35    Male     No  Sat  Dinner     3
# 20        17.92  4.08    Male     No  Sat  Dinner     2
# 21        20.29  2.75  Female     No  Sat  Dinner     2
# 22        15.77  2.23  Female     No  Sat  Dinner     2
# 23        39.42  7.58    Male     No  Sat  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [87 rows x 7 columns]

# %%
sns.catplot(x = "total_bill", y = "day", hue = "sex", kind = "violin", data = tips)

# %%
sns.catplot(x = "total_bill", y = "day", hue = "sex", kind = "violin", data = tips, split = True)

# %%
sns.catplot(x = "total_bill", y = "day", hue = "sex", kind = "violin", data = tips, split = True, inner = 'stick')

# %%
g = sns.catplot(x = "day", y = "total_bill", kind = "violin", inner = None, data = tips)
sns.swarmplot(x = "day", y = "total_bill", color = 'k', size = 3, data = tips, ax = g.ax)

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x = "sex", y = "survived", hue = "class", kind = "bar", data = titanic)

# %%
sns.catplot(x = "deck", kind = "count", palette = "ch:0.25", data = titanic)

# %%
sns.catplot(x = "deck", kind = "count", palette = "ch:0.25", data = titanic, hue = "class")

# %%
sns.catplot(x = "sex", y = "survived", hue = "class", kind = "point", data = titanic)

# %% [markdown]
# ### Visualizing the distribution of the data

# %%
### Univariate distribution
x = randn(100)

# %%
sns.distplot(x)

# %%
sns.distplot(x, kde = False)

# %%
sns.distplot(x, kde = False, rug = True)

# %%
sns.distplot(x, kde = False, rug = True, bins = 30)

# %%
sns.distplot(x, kde = True, hist = False, rug = True, bins = 30)

# %%
sns.distplot(x, kde = True, hist = False, rug = False, bins = 30)

# %%
sns.kdeplot(x)

# %%
sns.kdeplot(x, shade = True)

# %%
sns.kdeplot(x, shade = True, bw = 0.2)

# %%
sns.kdeplot(x, shade = True, bw = 1)

# %%
sns.kdeplot(x, shade = True, bw = 1, cut = 0)

# %%
sns.kdeplot(x, shade = True, bw = 1, cut = 10)

# %%
sns.kdeplot(x, shade = True, bw = 1, cut = 5)

# %%
### bivariate

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips['total_bill']
y = tips['tip']

# %%
sns.jointplot(x = x, y = y)

# %%
sns.set()
sns.jointplot(x = x, y = y, kind = "hex")

# %%
sns.jointplot(x = x, y = y, kind = "kde")

# %%
f, ax = plt.subplots(figsize = (6, 6))
cmap = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse = True)
sns.kdeplot(x, y, cmap = cmap, n_levels = 60, shade = True)

# %%
g = sns.jointplot(x, y, kind = "kde", color="m")

# %%
g = sns.jointplot(x, y, kind = "kde", color="m")
g.plot_joint(plt.scatter, c = "w", s = 30, linewidth = 1, marker = '+')
g.ax_joint.collections[0].set_alpha(0)

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x = "total_bill", y = "tip", data = tips)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = "total_bill", y = "tip", data = tips)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = "size", y = "tip", data = tips)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = "size", y = "tip", data = tips, x_jitter = 0.05)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = "size", y = "tip", data = tips, x_estimator = np.mean)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = "size", y = "tip", data = tips, x_estimator = np.median)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
data = sns.load_dataset('anscombe')

# %%
data.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
data["dataset"].unique()
# Out:
# array(['I', 'II', 'III', 'IV'], dtype=object)

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'I'"), ci = None, scatter_kws = {'s': 80})
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'II'"), ci = None, scatter_kws = {'s': 80})
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'II'"), ci = None, scatter_kws = {'s': 80}, order = 1)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'III'"), ci = None, scatter_kws = {'s': 80}, order = 1)
# Out:
# C:\Users\shash\AppData\Roaming\Python\Python38\site-packages\numpy\linalg\linalg.py:1965: RuntimeWarning: invalid value encountered in greater
#   large = s > cutoff

# %%
sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'III'"), ci = None, scatter_kws = {'s': 80}, robust = True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-147-571e633f094e> in <module>
# ----> 1 sns.lmplot(x = 'x', y = 'y', data = data.query("dataset == 'III'"), ci = None, scatter_kws = {'s': 80}, robust = True)
#
# c:\users\shash\appdata\local\programs\python\python38\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     614         scatter_kws=scatter_kws, line_kws=line_kws,
#     615         )
# --> 616     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     617
#     618     # Add a legend
#
# c:\users\shash\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     826
#     827             # Draw the plot
# --> 828             self._facet_plot(func, ax, args, kwargs)
#     829
#     830         # Finalize the annotations and layout
#
# c:\users\shash\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     844
#     845         # Draw the plot
# --> 846         func(*plot_args, **plot_kwargs)
#     847
#     848         # Sort out the supporting information
#
# c:\users\shash\appdata\local\programs\python\python38\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     815     scatter_kws["marker"] = marker
#     816     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 817     plotter.plot(ax, scatter_kws, line_kws)
#     818     return ax
#     819
#
# c:\users\shash\appdata\local\programs\python\python38\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     367
#     368         if self.fit_reg:
# --> 369             self.lineplot(ax, line_kws)
#     370
#     371         # Label the axes
#
# c:\users\shash\appdata\local\programs\python\python38\lib\site-packages\seaborn\regression.py in lineplot(self, ax, kws)
#     410         """Draw the model."""
#     411         # Fit the regression model
# --> 412         grid, yhat, err_bands = self.fit_regression(ax)
#     413         edges = grid[0], grid[-1]
#     414
#
# c:\users\shash\appdata\local\programs\python\python38\lib\site-packages\seaborn\regression.py in fit_regression(self, ax, x_range, grid)
#     213             grid, yhat = self.fit_lowess()
#     214         elif self.robust:
# --> 215             from statsmodels.robust.robust_linear_model import RLM
#     216             yhat, yhat_boots = self.fit_statsmodels(grid, RLM)
#     217         elif self.logx:
#
# ModuleNotFoundError: No module named 'statsmodels'
